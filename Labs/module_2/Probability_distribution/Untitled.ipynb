# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/Jeff/Downloads/espaces_verts (1).csv', sep=';')

# %%
df
# Out:
#    Identifiant espace vert       Nom de l'espace vert Typologie d'espace vert  \
# 0                      111            SQUARE D'ANVERS     Promenades ouvertes
# 1                      110  SQUARE D'ESTIENNE D'ORVES     Promenades ouvertes
# 2                      109           SQUARE MONTHOLON     Promenades ouvertes
# 3                      108             SQUARE BERLIOZ     Promenades ouvertes
# 4                      112       SQUARE ALEX BISCARRE     Promenades ouvertes
#
#   Catégorie  Adresse - Numéro Adresse - Complément Adresse - type voie  \
# 0    Square                 3                  NaN            PLACE D'
# 1    Square                 1                  NaN            PLACE D'
# 2    Square                79                  BIS                 RUE
# 3    Square                 1                  NaN               PLACE
# 4    Square                31                  BIS                 RUE
#
#   Adresse - Libellé voie  Code postal  Surface calculée  ...  \
# ...

# %%
df['Geo Shape'][0]
# Out:
# '{"type": "Polygon", "coordinates": [[[2.343934160248974, 48.88260024593223], [2.344010657634073, 48.882614638000796], [2.344006580903519, 48.88262369350842], [2.3440113948328, 48.88262463810149], [2.344076660275187, 48.882479661125494], [2.3440772152869522, 48.882479767589246], [2.3441210722927153, 48.882488165687526], [2.344120969811263, 48.882488398952106], [2.344083788860403, 48.882572905029356], [2.344055620219968, 48.882636926047276], [2.344055453169765, 48.88263730554896], [2.344060638639811, 48.882638307934116], [2.344092183509115, 48.88264466455439], [2.344112368321265, 48.88264873129069], [2.344112109138484, 48.882649280261205], [2.34411877749958, 48.88265066488918], [2.34411905621331, 48.88265008095174], [2.344120575726406, 48.88264690564521], [2.344121026819336, 48.88264595212784], [2.344120425683804, 48.88264582652568], [2.344124310943577, 48.8826372475102], [2.344195517023892, 48.88265136135793], [2.344195747282048, 48.882650943531075], [2.344203356841434, 48.8826524124
# ...

# %%
pd.json_normalize(df['Geo Shape'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-8ae7d0b4300c> in <module>
# ----> 1 pd.json_normalize(df['Geo Shape'])
#
# /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages/pandas/io/json/_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     268
#     269     if record_path is None:
# --> 270         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     271             # naive normalization, this is idempotent for flat records
#     272             # and potentially will inflate the data considerably for
#
# /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages/pandas/io/json/_normalize.py in <genexpr>(.0)
#     268
#     269     if record_path is None:
# --> 270         if any([isinstance(x, dict) for x in y.values()] for y in data):
# ...
